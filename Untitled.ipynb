# %%
from siftdetector import detect_keypoints

# %%
img = cv2.imread('./coast/art294.jpg')
# %matplotlib inline
from numpy_sift import SIFTDescriptor 
import matplotlib.pyplot as plt
patch_size = 65
SD = SIFTDescriptor(patchSize = patch_size)

import sys
sys.path.insert(0, '/home/ubuntu/dev/opencv-3.1/build/lib')
import cv2
import time

image = cv2.imread('coast/art294.jpg',0)
plt.figure()
plt.imshow(image, cmap="gray")

h,w = image.shape
patch = image[h/4: h/4 + patch_size,w/3 : w/3 + patch_size]
plt.figure()
plt.imshow(patch, cmap="gray")

t = time.time()
sift = SD.describe(patch)
print 'time', time.time() - t
print sift
# Out:
# time 0.018709897995
# [  2   3   6   7  27  24  45  38  47  37  51  36  15  50  39  25   9  11
#   12   6  23  16  25  21  21  35  26  18  20  30  31  30  37  48  21   7
#   34  30  25  12  12  36  36  21  59  49  53  47   3   5   5   6  25  22
#   36  36  48  53  51  59  43  60  53  26   0   1   3   6  24  37  41  58
#   44  50  40  54  23  38  40  23   3  19  70  44  43  94 110  58  25  31
#   25  20  36  38  42  34  63  93  88  86 110 110 110  57  29  38  42  32
#   46  69  67  54  16  22  13  21  48  73  72  57  53  46  70  44  36  67
#   50  27]
